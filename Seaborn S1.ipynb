# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize']=(10,6)

# %% [markdown]
# # Seaborn
#
# Matplotlib has proven to be an incredibly useful and popular visualization tool, but even avid users will admit it often leaves much to be desired.
# There are several valid complaints about Matplotlib that often come up:
#
# - Prior to version 2.0, Matplotlib's defaults(themes) are not exactly the best choices. It was based off of MATLAB circa 1999, and this often shows.
# - Matplotlib's API is relatively low level(lets the user do all the work). Doing sophisticated statistical visualization is possible, but often requires a *lot* of boilerplate code.
# - Matplotlib predated Pandas by more than a decade, and thus is not designed for use with Pandas ``DataFrame``s.
# From Ernest Musyoki to Everyone 07:50 PM
# An answer to these problems is [Seaborn](http://seaborn.pydata.org/). Seaborn provides an API on top of Matplotlib that offers same choices for plot style and color defaults, defines simple high-level functions for common statistical plot types, and integrates with the functionality provided by Pandas ``DataFrame``s.
#
# To be fair, the Matplotlib team is addressing this: it has recently added the ``plt.style`` tools discussed, and is starting to handle Pandas data more seamlessly.
# The 2.0 release of the library will include a new default stylesheet that will improve on the current status quo.
# But for all the reasons just discussed, Seaborn remains an extremely useful addon.
#
# For more detailed information about Seaborn, check out the site at https://seaborn.pydata.org/
#
# Seaborn uses fewer code and has stunning default themes.

# %%
import seaborn as sns

# %%
 sns._version_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-4f44ecf590bd> in <module>
# ----> 1 sns._version_
#
# AttributeError: module 'seaborn' has no attribute '_version_'

# %%
sns.__version__

# %%
sns.__version__

# %% [markdown]
# Import Data

# %%
df=pd.read_csv('seaborn_data.csv')

# %% [markdown]
# ### seaborn theme
# We can set the seaborn theme, for all visualizations  including matplotlib in the notebook.

# %%
plt.plot(df['loan_amount'],df['lender_count'])
plt.show()

# %% [markdown]
# Seaborn supports various themes that can make styling the plots really easy and save a lot of time. Using the set_style() function of Seaborn we can set any of the themes available on Seaborn library. Here are a few of the popular themes:
#
# * darkgrid
# * whitegrid
# * dark
# * white
# * ticks
#
# The default theme of the plot will be Darkgrid which we have seen in the previous exampl

# %%
sns.set_style('darkgrid')

# %%
plt.plot(df['loan_amount'],df['lender_count'])
plt.show()

# %% [markdown]
# Seaborn also gives us the freedom to create customized themes in the set function.

# %%
sns.set(rc={"axes.facecolor":"#662fef","axes.grid":True})

# %%
plt.plot(df['loan_amount'],df['lender_count'])
plt.show()

# %%
sns.set() ##resets back to default theme

# %% [markdown]
# We have 5 main categories of plots in seaborn:
#
# * Categorical plots
# * Relational plots
# * Distribution plots
# * Joint plots
# * Matrix plots

# %% [markdown]
# ## Categorical Plots
#
#
# There are several types. For this class we shall only look at the `barplot()`. For more, check out the documentation at https://seaborn.pydata.org/api.html (for the APIs) and https://seaborn.pydata.org/tutorial/categorical.html (for tutorials)
#
# Bar plots help you visualize the distributions of categorical variables.
#
# Syntax:
# ```Python
# sns.barplot()
# ```

# %%
sns.barplot(data = df, x = 'sector', y = 'loan_amount') #ci = None)

plt.show()

# %%
sns.set()

# %%
sns.barplot(data = df, x = 'sector', y = 'loan_amount') #ci = None)

plt.show()

# %% [markdown]
# Matplotlib way

# %%
sns.barplot(x=df['sector'], y=df['loan_amount'])
plt.show()

# %% [markdown]
# Removing the error bars

# %%
sns.barplot(data = df, x = 'sector', y = 'loan_amount',ci = None)

plt.show()

# %% [markdown]
# ### List of estimators
#
#     Min 	np.min()
#     Max 	np.max()
#     Mean 	np.mean()
#     Median 	 np.median()
#     Standard_deviation  np.std()
#     Average    np.average()
#     Percentile   np.percentile()

# %% [markdown]
# Change Estimator

# %%
sns.barplot(data = df, x = 'sector', y = 'loan_amount',ci = None, estimator=np.sum)

plt.show()

# %% [markdown]
# Customization

# %%
plt.title('Loan amount by Sector')
plt.xticks(rotation = 90)
plt.ticklabel_format(style='plain')
sns.barplot(data = df, x = 'sector', y = 'loan_amount',ci = None, estimator=np.sum)

plt.show()

# %% [markdown]
# Sorting Bars

# %%
df.groupby('sector')['loan_amount'].sum().sort_values(ascending=False)

# %%
descending = df.groupby('sector')['loan_amount'].sum().sort_values(ascending = False).index

# %%
ascending = df.groupby('sector')['loan_amount'].sum().sort_values(ascending = True).index

# %%
df=pd.read_csv('seaborn_data.csv')

# %%
plt.title('Loan amount by Sector')
plt.xticks(rotation = 90)
plt.ticklabel_format(style='plain')

sns.barplot(data = df, x = 'sector', y = 'loan_amount', ci = None, estimator = np.sum, order = descending)

plt.show()

# %% [markdown]
# ##### Seaborn Color Palette(color combination)
#
# Seaborn has a reputation for making plots and graphs more attractive using
# ##### Seaborn Color Palette(color combination)
#
# Seaborn has a reputation for making plots and graphs more attractive using attractive colors and color combinations. In data visualization, color is necessarily involved, and colors have an influence on their observer.It plays an important role than any other aspect in the visualizations. When used effectively, color adds more value to the plot.
#
# A palette refers to the flat surface on which a painter arranges and mixes paints. Here we have some of the color palettes out of the 170 palettes offered by Seaborn.
#
# Here is a list of palettes you can try out on your own.

# %%
'['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 
'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap',
 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 
'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 
'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r',
 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 
'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 
'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 
'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu',
 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r',
 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 
'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia',
 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r',
 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 
'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r',
 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis',
 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 
'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 
'flag_r']'

# %%
plt.title('Loan amount by Sector')
plt.xticks(rotation = 90)
plt.ticklabel_format(style='plain')

sns.barplot(data = df, x = 'sector', y = 'loan_amount', ci = None, estimator = np.sum, order = descending,color='red')

plt.show()

# %% [markdown]
# Using color Palette

# %%
plt.title('Loan amount by Sector')
plt.xticks(rotation = 90)
plt.ticklabel_format(style='plain')

sns.barplot(data = df, x = 'sector', y = 'loan_amount', ci = None, estimator = np.sum, order = descending, palette= 'Greens_r')

plt.show()

# %% [markdown]
# ### Horizontal bar plot
#
# To get a horizontal plot, just switch the values for x and y axes.Categorical values on the Y axis and numerical on the x.

# %%
sns.barplot(data = df, x = 'loan_amount', y ='sector', ci = None, estimator = np.sum, color = 'red' )

plt.show()

# %% [markdown]
# Grouped BarPlot

# %%
plt.title('Loan amount by Sector')
plt.xticks(rotation = 90)
plt.ticklabel_format(style='plain')

sns.barplot(data = df, x = 'sector', y = 'loan_amount', ci = None, estimator = np.sum, order = descending, palette = 'Dark2_r')

plt.show()

# %%
plt.title('Loan amount by Sector')
plt.xticks(rotation = 90)
plt.ticklabel_format(style='plain')

sns.barplot(data = df, x = 'sector', y = 'loan_amount', ci = None, estimator = np.sum, order = descending,
            palette = 'Dark2_r', hue = 'gender_lead')

plt.show()

# %%
plt.title('Loan amount by Sector')
plt.xticks(rotation = 90)
plt.ticklabel_format(style='plain')

sns.barplot(data = df, x = 'sector', y = 'loan_amount', ci = None, estimator = np.sum, order = descending,
            palette = 'Dark2_r', hue = 'repayment_interval')

plt.show()

# %% [markdown]
# Countplot

# %%
df['sector'].value_counts()
# Out:
# Agriculture       476
# Retail            369
# Food              368
# Services          338
# Clothing          251
# Transportation    175
# Education         174
# Construction      158
# Personal Use      144
# Housing           111
# Manufacturing     100
# Health             88
# Arts               53
# Entertainment      24
# Wholesale          19
# Name: sector, dtype: int64

# %%
plt.xticks(rotation = 90)
sns.countplot(data=df,x='sector')
plt.show()

# %% [markdown]
# ### Box Plot
# Shows the distribution of values across the interquartile ranges.It is mostly used to detect outlier in the data.
#
# A box plot is composed of a summary of 5 sections: the minimum, first quartile, median, third quartile, and maximum.
#
#     Minimum
#     First Quartile or 25%
#     Median (Second Quartile) or 50%
#     Third Quartile or 75%
#     Maximum

# %%
plt.xticks(rotation = 90)
sns.boxplot(data = df, x = 'sector', y= 'average_count')
plt.show()

# %% [markdown]
# ## Relational Plots
# There is the `relplot()` function which is used as the generic form of relational plot, within which you can call the `scatterplot()` (the default) or the `lineplot()`. In this session, we will focus on the `scatterplot()`. For more details on these plots, check out the documentation at https://seaborn.pydata.org/api.html (for the APIs) and https://seaborn.pydata.org/tutorial/relational.html (for the tutorial)
#
# #### Scatterplot
# Show relationships between numerical variables.

# %%
sns.scatterplot(data = df, x = 'lender_count', y = 'loan_amount')

plt.show()

# %%
sns.scatterplot(data = df, x = 'lender_count', y = 'loan_amount')
plt.ticklabel_format(style='plain')

plt.show()

# %%
df['lender_count'].corr(df['loan_amount'])
# Out:
# 0.9971793758477521

# %%
sns.scatterplot(data = df, x = 'lender_count', y = 'loan_amount', hue ='sector')
plt.ticklabel_format(style='plain')

plt.show()

# %%
sns.scatterplot(data = df, x = 'lender_count', y = 'loan_amount', style ='gender_lead')
plt.ticklabel_format(style='plain')

plt.show()

# %%
sns.scatterplot(data = df, x = 'lender_count', y = 'loan_amount', size ='loan_amount',sizes =(200,800))
plt.ticklabel_format(style='plain')

plt.show()

# %% [markdown]
# ## Distribution Plots
# Of three types, `histplot()`, `kdeplot()` and `rugplot()`. The parent plotting function is the `displot()`, which by default results in a histogram.
#
# For the other kinds, check out https://seaborn.pydata.org/api.html (for the APIs) and https://seaborn.pydata.org/tutorial/distributions.html (for the tutorial).
#
# We can use the parent function *displot()* to plot either of these plots.
#
# Histogram
#
# By defualt it plots the histogram.

# %% [markdown]
# kde plot
#
# In statistics, kernel density estimation (KDE) is a non-parametric way to estimate the probability density function of a random variable. Kernel density estimation is a fundamental data smoothing problem where inferences about the population are made, based on a finite data sample.
#
# To learn more about it, check out https://en.wikipedia.org/wiki/Kernel_density_estimation).

# %%
sns.histplot(data=df,x='average_count')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.histplot(data=df,x='average_count', bins = 10)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# kde plot
#
# In statistics, kernel density estimation (KDE) is a non-parametric way to estimate the probability density function of a random variable. Kernel density estimation is a fundamental data smoothing problem where inferences about the population are made, based on a finite data sample.
#
# To learn more about it, check out https://en.wikipedia.org/wiki/Kernel_density_estimation).

# %%
sns.kdeplot(data=df,x='average_count')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Rugplot

# %%
sns.rugplot(data=df,x='average_count')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Joint Plot

# %% [markdown]
# Combines information from scatter plots and histograms to give you detailed information for bi-variate distributions

# %%
census=pd.read_excel('census_merged.xlsx')
census.head()
# Out:
#      County  Population  Households  Average Household Size    Area  Density
# 0   Nairobi     4337080     1506888                    31.6   703.7   180387
# 1    Kiambu     2402834      795241                    40.5  2538.7    17054
# 2    Nakuru     2142667      616046                    39.9  7462.5     6165
# 3  Kakamega     1861332      433207                    56.3  3020.1     8742
# 4   Bungoma     1663898      358796                    56.6  3023.9     7510

# %%
sns.jointplot(data=census, x = 'Population', y='Households')
plt.ticklabel_format(style='plain')
plt.show()

# %% [markdown]
# # Matrix Plots
# These are the sns.heatmap() and sns.clustermap(). Heatmaps are used to visualize intensity of values of the different numerical variables in a matrix or table.
# To generate a heatmap, we need to generate a table of correaltions from the dataframe

# %%
df_corr=census.corr()

# %%
sns.heatmap(df_corr)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.heatmap(df_corr, cmap='coolwarm')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.heatmap(df_corr, cmap='YlGnBu',annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Pairplot

# %%
sns.pairplot(census)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
